# %% [markdown]
# # **PROYECTO TFM**
#  ## Segmentación e Identificación de Edificios en Imágenes Satelitales
#
# ## Objetivo
# El objetivo de este trabajo es desarrollar un modelo de segmentación semántica capaz de identificar edificios en imágenes satelitales de alta resolución, utilizando datasets públicos (SpaceNet, Mapping Challenge, Inria y Massachusetts) y redes neuronales convolucionales.

# %% [markdown]
# Importacion de librerias

# %%
# Importacion de liberias necesarias para el programa
#import imageio
import cv2
from skimage import measure, morphology
from scipy import ndimage
# ============================================
# 📦 Librerías básicas y utilidades
# ============================================
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import colors
import os
import random
from skimage.feature import peak_local_max
from skimage.filters import gaussian
from skimage.segmentation import watershed
from scipy import ndimage as ndi
from skimage.measure import label
from skimage.morphology import local_maxima
from scipy.ndimage import gaussian_filter, binary_fill_holes
#from PIL import Image
# ============================================
# 🧠 TensorFlow / Keras
# ============================================
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory
#from tensorflow.data import *
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.callbacks import *
from tensorflow.keras.applications import *
from tensorflow.keras.optimizers import *
from tensorflow.keras import *
from keras_unet_collection import transformer_layers
from keras_unet_collection import models
import warnings
warnings.filterwarnings("ignore", category=UserWarning)
# Primero se comprueba si tenemos la GPU instalada
print("TensorFlow:", tf.__version__)
print("GPU detectada:", tf.config.list_physical_devices('GPU'))
# Out:
# TensorFlow: 2.10.0
# GPU detectada: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %% [markdown]
# Preparación del entorno de trabajo y procesamiento (pre y pos) de imágenes (incluyendo data augmentation)

# %%
# ============================================
# Direccion de los datasets
# ============================================
dataset_final = "../DATASETS/DATASET_FINAL/splits_300"
train_dir = f"{dataset_final}/train"
val_dir = f"{dataset_final}/val"
test_dir = f"{dataset_final}/test"


# ============================================
# Configuracion del dataset (tamaño, tipo...)
# ============================================
# Cantidad de datos (se reduce por disminuir tiempo de entrenamiento)
#cantida_imagenes_entrenamiento = 116666
cantida_imagenes_entrenamiento = 46667
# cantida_imagenes_entrenamiento = 77777
#cantida_imagenes_entrenamiento = 58333
cantida_imagenes_validacion   = 14582
cantida_imagenes_test  = 14581
#cantida_imagenes_validacion   = 19444
#cantida_imagenes_test  = 19445

# Configuraciones para cargar las imagenes
ancho_imagen, alto_imagen = 128, 128  # Tamaños de la imagen
batch_size = 6 # Tamaño de batch para el entrenamiento
seed = 42 # Para evitar aleatoridad a la hora de entrenar el modelo
AUTOTUNE = tf.data.AUTOTUNE # Para acelerar el pipeline de datos

# %%
#############################################
#--------------------------------------------
# Disminuir tamaño dataset
#--------------------------------------------
#############################################

# Disminuimos el tamaño del dataset para disminuir el tiempo del entrenamiento
def coger_dataset_pequenio(image_dir, mask_dir, n):
    # Listado de archivos
    image_files = sorted([f for f in os.listdir(image_dir) if f.endswith(".png")]) # Listamos las imagenes en un orden
    mask_files = sorted([f for f in os.listdir(mask_dir) if f.endswith(".png")]) # Listamos las mascaras en un orden (asi se "junta" con la imagen)

    # Mezclar y tomar n archivos
    combined = list(zip(image_files, mask_files))
    #random.seed(42) # Garantiza la reproducibiliadad
    #random.shuffle(combined)
    subset = combined[:n]

    subset_images = [os.path.join(image_dir, x[0]) for x in subset]
    subset_masks  = [os.path.join(mask_dir, x[1]) for x in subset]

    # Crear tf.data.Dataset
    ds = tf.data.Dataset.from_tensor_slices((subset_images, subset_masks))
    ds = ds.shuffle(buffer_size=len(subset), seed=42, reshuffle_each_iteration=True)
    return ds

# Cogemos los 3 dataset con la funcion para dismiuir el tamaño y tiempo den entrenamiento

# Imagenes para train
train_ds_small = coger_dataset_pequenio(os.path.join(train_dir,"images"),
                                        os.path.join(train_dir,"masks"),
                             cantida_imagenes_entrenamiento)

# Imagenes para val
val_ds_small = coger_dataset_pequenio(os.path.join(val_dir,"images"),
                                      os.path.join(val_dir,"masks"),
                           cantida_imagenes_validacion)

# Imagenes para test
test_ds_small = coger_dataset_pequenio(os.path.join(test_dir,"images"),
                                       os.path.join(test_dir,"masks"),
                            cantida_imagenes_test)

# %% [markdown]
# Tras reducir el tamanio y descubri que tf.data.Dataset.from_tensor_slices une las máscaras y las imagenes más facilmente se opto por eliminar tf.keras.utils.image_dataset_from_directory

# %%
def cargar_imagenes_mascaras(image_dir, mask_dir, aplicar_data_augmentation):
    # Leemos la imagen
    image = tf.io.read_file(image_dir) # Lectura de imagen
    image = tf.image.decode_png(image, channels=3) # Decoder los canales (RGB)
    image = tf.image.resize(image, [ancho_imagen, alto_imagen]) # Ajustamos el ancho y el alto a la configuracion anterior
    image = tf.cast(image, tf.float32)/255.0 # Normalizamos la imagen

    # Leemos la máscara (igual que en imagen pero en un solo canal en este caso)
    mask = tf.io.read_file(mask_dir)
    mask = tf.image.decode_png(mask, channels=1)
    mask = tf.image.resize(mask, [ancho_imagen, alto_imagen])
    mask = tf.cast(mask > 0, tf.float32)

    # Aplicamos data augmentation (opcional pero recomendable)
    if aplicar_data_augmentation:
        # Flip horizontal si es mayor de 0.5
        if tf.random.uniform(()) > 0.5:
            image = tf.image.flip_left_right(image)
            mask  = tf.image.flip_left_right(mask)
        # Flip vertical si es mayor de 0.5
        if tf.random.uniform(()) > 0.5:
            image = tf.image.flip_up_down(image)
            mask  = tf.image.flip_up_down(mask)
        # Rotación 90° aleatoria
        k = tf.random.uniform((), minval=0, maxval=4, dtype=tf.int32)
        image = tf.image.rot90(image, k)
        mask  = tf.image.rot90(mask, k)
        # Cambios de brillo/contraste solo en la imagen
        image = tf.image.random_brightness(image, 0.2)
        image = tf.image.random_contrast(image, 0.8, 1.2)
        image = tf.image.random_saturation(image, lower=0.8, upper=1.2)

        # Recorte aleatorio (simula zoom)
        combined = tf.concat([image, mask], axis=-1)  # unir para que ambos se recorten igual
        combined = tf.image.random_crop(combined, size=[alto_imagen, ancho_imagen, 4])
        image = combined[..., :3]
        mask  = combined[..., 3:]
    # Después de todas las augmentations
    image = tf.clip_by_value(image, 0.0, 1.0)
    mask = tf.clip_by_value(mask, 0.0, 1.0)
    # Asegurar la forma correcta
    image = tf.reshape(image, [alto_imagen, ancho_imagen, 3])
    mask  = tf.reshape(mask, [alto_imagen, ancho_imagen, 1])
    return image, mask

# %%
train_ds_unet = (
    train_ds_small
        .map(lambda x, y: cargar_imagenes_mascaras(x, y, aplicar_data_augmentation=True),
             num_parallel_calls=AUTOTUNE)
        .shuffle(3000)       # barajar solo entrenamiento
        .batch(batch_size)   # agrupar en batches
        .prefetch(AUTOTUNE)  # cargar el siguiente batch mientras la GPU entrena
)

val_ds_unet = (
    val_ds_small
        .map(lambda x, y: cargar_imagenes_mascaras(x, y, aplicar_data_augmentation=False),
             num_parallel_calls=AUTOTUNE)
        .batch(batch_size)
        .prefetch(AUTOTUNE)
)

test_ds_unet = (
    test_ds_small
        .map(lambda x, y: cargar_imagenes_mascaras(x, y, aplicar_data_augmentation=False),
             num_parallel_calls=AUTOTUNE)
        .batch(batch_size)
        .prefetch(AUTOTUNE)
)

# %%
for imgs, masks in train_ds_unet.take(1):
    print(imgs.shape, masks.shape)
# Out:
# (6, 128, 128, 3) (6, 128, 128, 1)

# %%
# Ahora visualizamos 4 imagenes con sus máscaras para ver como va
num_examples = 4  # cuántas imágenes del batch quieres mostrar
plt.figure(figsize=(12, 6))
# Tomamos solo un batch
for images, masks in train_ds_unet.take(1):
    break  # images: (batch_size, alto, ancho, 3), masks: (batch_size, alto, ancho, 1)
for i in range(num_examples):
    # Imagen
    plt.subplot(num_examples, 2, 2*i + 1)
    plt.imshow(tf.clip_by_value(images[i], 0.0, 1.0).numpy())  # clip para evitar warnings
    plt.title("Imagen")
    plt.axis("off")

    # Máscara
    plt.subplot(num_examples, 2, 2*i + 2)
    plt.imshow(tf.clip_by_value(masks[i], 0.0, 1.0).numpy().squeeze(), cmap='gray')
    plt.title("Máscara")
    plt.axis("off")

plt.tight_layout()
plt.show()

# %%
# Forma correcta para tu U-Net clásico
#img_size = (alto_imagen, ancho_imagen)  # solo alto y ancho
#num_classes = 1
# Modelo TransUNet ligero
model = models.transunet_2d(
    input_size=(alto_imagen, ancho_imagen, 3),
    filter_num=[64, 128, 256, 512],
    n_labels=1,
    stack_num_down=2,
    stack_num_up=2,
    embed_dim=512,
    num_heads=8,
    num_transformer=4,
    batch_norm=True,
    pool=True,
    unpool='bilinear',
    output_activation='Sigmoid'
)
#model = models.transunet_2d(
   # input_size=(alto_imagen, ancho_imagen, 3),
   # filter_num=[64, 128, 256, 512],
    #n_labels=1,
    #stack_num_down=2,
   # stack_num_up=2,
   # embed_dim=768,
    #num_mlp=3072,
   # num_heads=12,
    #num_transformer=6,
   # activation='ReLU',
    #mlp_activation='GELU',
    #output_activation='Sigmoid',
    #batch_norm=True, pool=True,
    #unpool='bilinear',
    #name='transunet'
#)

# %%
policy = mixed_precision.Policy('mixed_float16')
mixed_precision.set_global_policy(policy)
model.summary()
# Out:
# INFO:tensorflow:Mixed precision compatibility check (mixed_float16): OK
# Your GPU will likely run quickly with dtype policy mixed_float16 as it has compute capability of at least 7.0. Your GPU: NVIDIA GeForce RTX 3070 Ti, compute capability 8.6
# Model: "transunet_model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  transunet_down0_0 (Conv2D)     (None, 128, 128, 64  1728        ['input_1[0][0]']
#                                 )
#
#  transunet_down0_0_bn (BatchNor  (None, 128, 128, 64  256        ['transunet_down0_0[0][0]']
#  malization)                    )
#
#  transunet_down0_0_activation (  (None, 128, 128, 64  0          ['transunet_down0_0_bn[0][0]']
#  ReLU)                          )
#
#  transunet_down0_1 (Conv2D)     (None, 128, 128, 64  36864       ['transunet_down0_0_activation[0]
#                                 )                                [0]']
#
#  transunet_down0_1_bn (BatchNor  (None, 128, 128, 64  256        ['transunet_down0_1[0][0]']
#  malization)                    )
#
#  transunet_down0_1_activation (  (None, 128, 128, 64  0          ['transunet_down0_1_bn[0][0]']
#  ReLU)                          )
#
#  transunet_down1_encode_maxpool  (None, 64, 64, 64)  0           ['transunet_down0_1_activation[0]
#   (MaxPooling2D)                                                 [0]']
#
#  transunet_down1_conv_0 (Conv2D  (None, 64, 64, 128)  73728      ['transunet_down1_encode_maxpool[
#  )                                                               0][0]']
#
#  transunet_down1_conv_0_bn (Bat  (None, 64, 64, 128)  512        ['transunet_down1_conv_0[0][0]']
#  chNormalization)
#
#  transunet_down1_conv_0_activat  (None, 64, 64, 128)  0          ['transunet_down1_conv_0_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  transunet_down1_conv_1 (Conv2D  (None, 64, 64, 128)  147456     ['transunet_down1_conv_0_activati
#  )                                                               on[0][0]']
#
#  transunet_down1_conv_1_bn (Bat  (None, 64, 64, 128)  512        ['transunet_down1_conv_1[0][0]']
#  chNormalization)
#
#  transunet_down1_conv_1_activat  (None, 64, 64, 128)  0          ['transunet_down1_conv_1_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  transunet_down2_encode_maxpool  (None, 32, 32, 128)  0          ['transunet_down1_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  transunet_down2_conv_0 (Conv2D  (None, 32, 32, 256)  294912     ['transunet_down2_encode_maxpool[
#  )                                                               0][0]']
#
#  transunet_down2_conv_0_bn (Bat  (None, 32, 32, 256)  1024       ['transunet_down2_conv_0[0][0]']
#  chNormalization)
#
#  transunet_down2_conv_0_activat  (None, 32, 32, 256)  0          ['transunet_down2_conv_0_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  transunet_down2_conv_1 (Conv2D  (None, 32, 32, 256)  589824     ['transunet_down2_conv_0_activati
#  )                                                               on[0][0]']
#
#  transunet_down2_conv_1_bn (Bat  (None, 32, 32, 256)  1024       ['transunet_down2_conv_1[0][0]']
#  chNormalization)
#
#  transunet_down2_conv_1_activat  (None, 32, 32, 256)  0          ['transunet_down2_conv_1_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  transunet_down3_encode_maxpool  (None, 16, 16, 256)  0          ['transunet_down2_conv_1_activati
#   (MaxPooling2D)                                                 on[0][0]']
#
#  transunet_down3_conv_0 (Conv2D  (None, 16, 16, 512)  1179648    ['transunet_down3_encode_maxpool[
#  )                                                               0][0]']
#
#  transunet_down3_conv_0_bn (Bat  (None, 16, 16, 512)  2048       ['transunet_down3_conv_0[0][0]']
#  chNormalization)
#
#  transunet_down3_conv_0_activat  (None, 16, 16, 512)  0          ['transunet_down3_conv_0_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  transunet_down3_conv_1 (Conv2D  (None, 16, 16, 512)  2359296    ['transunet_down3_conv_0_activati
#  )                                                               on[0][0]']
#
#  transunet_down3_conv_1_bn (Bat  (None, 16, 16, 512)  2048       ['transunet_down3_conv_1[0][0]']
#  chNormalization)
#
#  transunet_down3_conv_1_activat  (None, 16, 16, 512)  0          ['transunet_down3_conv_1_bn[0][0]
#  ion (ReLU)                                                      ']
#
#  transunet_conv_trans_before (C  (None, 16, 16, 512)  262144     ['transunet_down3_conv_1_activati
#  onv2D)                                                          on[0][0]']
#
#  patch_extract (patch_extract)  (None, 256, 512)     0           ['transunet_conv_trans_before[0][
#                                                                  0]']
#
#  patch_embedding (patch_embeddi  (None, 256, 512)    393728      ['patch_extract[0][0]']
#  ng)
#
#  transunet_ViT_0_layer_norm_1 (  (None, 256, 512)    1024        ['patch_embedding[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_0_atten (MultiHe  (None, 256, 512)    8401408     ['transunet_ViT_0_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_0_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_0_skip_1 (Add)   (None, 256, 512)     0           ['transunet_ViT_0_atten[0][0]',
#                                                                   'patch_embedding[0][0]']
#
#  transunet_ViT_0_layer_norm_2 (  (None, 256, 512)    1024        ['transunet_ViT_0_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_0_mlp_dense_0 (D  (None, 256, 3072)   1575936     ['transunet_ViT_0_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_0_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_0_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_0_mlp_dense_1 (D  (None, 256, 512)    1573376     ['transunet_ViT_0_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_0_mlp_activation  (None, 256, 512)    0           ['transunet_ViT_0_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_0_skip_2 (Add)   (None, 256, 512)     0           ['transunet_ViT_0_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_0_skip_1[0][0]']
#
#  transunet_ViT_1_layer_norm_1 (  (None, 256, 512)    1024        ['transunet_ViT_0_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_1_atten (MultiHe  (None, 256, 512)    8401408     ['transunet_ViT_1_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_1_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_1_skip_1 (Add)   (None, 256, 512)     0           ['transunet_ViT_1_atten[0][0]',
#                                                                   'transunet_ViT_0_skip_2[0][0]']
#
#  transunet_ViT_1_layer_norm_2 (  (None, 256, 512)    1024        ['transunet_ViT_1_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_1_mlp_dense_0 (D  (None, 256, 3072)   1575936     ['transunet_ViT_1_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_1_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_1_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_1_mlp_dense_1 (D  (None, 256, 512)    1573376     ['transunet_ViT_1_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_1_mlp_activation  (None, 256, 512)    0           ['transunet_ViT_1_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_1_skip_2 (Add)   (None, 256, 512)     0           ['transunet_ViT_1_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_1_skip_1[0][0]']
#
#  transunet_ViT_2_layer_norm_1 (  (None, 256, 512)    1024        ['transunet_ViT_1_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_2_atten (MultiHe  (None, 256, 512)    8401408     ['transunet_ViT_2_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_2_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_2_skip_1 (Add)   (None, 256, 512)     0           ['transunet_ViT_2_atten[0][0]',
#                                                                   'transunet_ViT_1_skip_2[0][0]']
#
#  transunet_ViT_2_layer_norm_2 (  (None, 256, 512)    1024        ['transunet_ViT_2_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_2_mlp_dense_0 (D  (None, 256, 3072)   1575936     ['transunet_ViT_2_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_2_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_2_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_2_mlp_dense_1 (D  (None, 256, 512)    1573376     ['transunet_ViT_2_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_2_mlp_activation  (None, 256, 512)    0           ['transunet_ViT_2_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_2_skip_2 (Add)   (None, 256, 512)     0           ['transunet_ViT_2_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_2_skip_1[0][0]']
#
#  transunet_ViT_3_layer_norm_1 (  (None, 256, 512)    1024        ['transunet_ViT_2_skip_2[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_3_atten (MultiHe  (None, 256, 512)    8401408     ['transunet_ViT_3_layer_norm_1[0]
#  adAttention)                                                    [0]',
#                                                                   'transunet_ViT_3_layer_norm_1[0]
#                                                                  [0]']
#
#  transunet_ViT_3_skip_1 (Add)   (None, 256, 512)     0           ['transunet_ViT_3_atten[0][0]',
#                                                                   'transunet_ViT_2_skip_2[0][0]']
#
#  transunet_ViT_3_layer_norm_2 (  (None, 256, 512)    1024        ['transunet_ViT_3_skip_1[0][0]']
#  LayerNormalization)
#
#  transunet_ViT_3_mlp_dense_0 (D  (None, 256, 3072)   1575936     ['transunet_ViT_3_layer_norm_2[0]
#  ense)                                                           [0]']
#
#  transunet_ViT_3_mlp_activation  (None, 256, 3072)   0           ['transunet_ViT_3_mlp_dense_0[0][
#  _0 (GELU)                                                       0]']
#
#  transunet_ViT_3_mlp_dense_1 (D  (None, 256, 512)    1573376     ['transunet_ViT_3_mlp_activation_
#  ense)                                                           0[0][0]']
#
#  transunet_ViT_3_mlp_activation  (None, 256, 512)    0           ['transunet_ViT_3_mlp_dense_1[0][
#  _1 (GELU)                                                       0]']
#
#  transunet_ViT_3_skip_2 (Add)   (None, 256, 512)     0           ['transunet_ViT_3_mlp_activation_
#                                                                  1[0][0]',
#                                                                   'transunet_ViT_3_skip_1[0][0]']
#
#  tf.reshape (TFOpLambda)        (None, 16, 16, 512)  0           ['transunet_ViT_3_skip_2[0][0]']
#
#  transunet_conv_trans_after (Co  (None, 16, 16, 512)  262144     ['tf.reshape[0][0]']
#  nv2D)
#
#  transunet_up0_decode_unpool (U  (None, 32, 32, 512)  0          ['transunet_conv_trans_after[0][0
#  pSampling2D)                                                    ]']
#
#  transunet_up0_conv_before_conc  (None, 32, 32, 256)  1179648    ['transunet_up0_decode_unpool[0][
#  at_0 (Conv2D)                                                   0]']
#
#  transunet_up0_conv_before_conc  (None, 32, 32, 256)  1024       ['transunet_up0_conv_before_conca
#  at_0_bn (BatchNormalization)                                    t_0[0][0]']
#
#  transunet_up0_conv_before_conc  (None, 32, 32, 256)  0          ['transunet_up0_conv_before_conca
#  at_0_activation (ReLU)                                          t_0_bn[0][0]']
#
#  transunet_up0_concat (Concaten  (None, 32, 32, 512)  0          ['transunet_up0_conv_before_conca
#  ate)                                                            t_0_activation[0][0]',
#                                                                   'transunet_down2_conv_1_activati
#                                                                  on[0][0]']
#
#  transunet_up0_conv_after_conca  (None, 32, 32, 256)  1179648    ['transunet_up0_concat[0][0]']
#  t_0 (Conv2D)
#
#  transunet_up0_conv_after_conca  (None, 32, 32, 256)  1024       ['transunet_up0_conv_after_concat
#  t_0_bn (BatchNormalization)                                     _0[0][0]']
#
#  transunet_up0_conv_after_conca  (None, 32, 32, 256)  0          ['transunet_up0_conv_after_concat
#  t_0_activation (ReLU)                                           _0_bn[0][0]']
#
#  transunet_up0_conv_after_conca  (None, 32, 32, 256)  589824     ['transunet_up0_conv_after_concat
#  t_1 (Conv2D)                                                    _0_activation[0][0]']
#
#  transunet_up0_conv_after_conca  (None, 32, 32, 256)  1024       ['transunet_up0_conv_after_concat
#  t_1_bn (BatchNormalization)                                     _1[0][0]']
#
#  transunet_up0_conv_after_conca  (None, 32, 32, 256)  0          ['transunet_up0_conv_after_concat
#  t_1_activation (ReLU)                                           _1_bn[0][0]']
#
#  transunet_up1_decode_unpool (U  (None, 64, 64, 256)  0          ['transunet_up0_conv_after_concat
#  pSampling2D)                                                    _1_activation[0][0]']
#
#  transunet_up1_conv_before_conc  (None, 64, 64, 128)  294912     ['transunet_up1_decode_unpool[0][
#  at_0 (Conv2D)                                                   0]']
#
#  transunet_up1_conv_before_conc  (None, 64, 64, 128)  512        ['transunet_up1_conv_before_conca
#  at_0_bn (BatchNormalization)                                    t_0[0][0]']
#
#  transunet_up1_conv_before_conc  (None, 64, 64, 128)  0          ['transunet_up1_conv_before_conca
#  at_0_activation (ReLU)                                          t_0_bn[0][0]']
#
#  transunet_up1_concat (Concaten  (None, 64, 64, 256)  0          ['transunet_up1_conv_before_conca
#  ate)                                                            t_0_activation[0][0]',
#                                                                   'transunet_down1_conv_1_activati
#                                                                  on[0][0]']
#
#  transunet_up1_conv_after_conca  (None, 64, 64, 128)  294912     ['transunet_up1_concat[0][0]']
#  t_0 (Conv2D)
#
#  transunet_up1_conv_after_conca  (None, 64, 64, 128)  512        ['transunet_up1_conv_after_concat
#  t_0_bn (BatchNormalization)                                     _0[0][0]']
#
#  transunet_up1_conv_after_conca  (None, 64, 64, 128)  0          ['transunet_up1_conv_after_concat
#  t_0_activation (ReLU)                                           _0_bn[0][0]']
#
#  transunet_up1_conv_after_conca  (None, 64, 64, 128)  147456     ['transunet_up1_conv_after_concat
#  t_1 (Conv2D)                                                    _0_activation[0][0]']
#
#  transunet_up1_conv_after_conca  (None, 64, 64, 128)  512        ['transunet_up1_conv_after_concat
#  t_1_bn (BatchNormalization)                                     _1[0][0]']
#
#  transunet_up1_conv_after_conca  (None, 64, 64, 128)  0          ['transunet_up1_conv_after_concat
#  t_1_activation (ReLU)                                           _1_bn[0][0]']
#
#  transunet_up2_decode_unpool (U  (None, 128, 128, 12  0          ['transunet_up1_conv_after_concat
#  pSampling2D)                   8)                               _1_activation[0][0]']
#
#  transunet_up2_conv_before_conc  (None, 128, 128, 64  73728      ['transunet_up2_decode_unpool[0][
#  at_0 (Conv2D)                  )                                0]']
#
#  transunet_up2_conv_before_conc  (None, 128, 128, 64  256        ['transunet_up2_conv_before_conca
#  at_0_bn (BatchNormalization)   )                                t_0[0][0]']
#
#  transunet_up2_conv_before_conc  (None, 128, 128, 64  0          ['transunet_up2_conv_before_conca
#  at_0_activation (ReLU)         )                                t_0_bn[0][0]']
#
#  transunet_up2_concat (Concaten  (None, 128, 128, 12  0          ['transunet_up2_conv_before_conca
#  ate)                           8)                               t_0_activation[0][0]',
#                                                                   'transunet_down0_1_activation[0]
#                                                                  [0]']
#
#  transunet_up2_conv_after_conca  (None, 128, 128, 64  73728      ['transunet_up2_concat[0][0]']
#  t_0 (Conv2D)                   )
#
#  transunet_up2_conv_after_conca  (None, 128, 128, 64  256        ['transunet_up2_conv_after_concat
#  t_0_bn (BatchNormalization)    )                                _0[0][0]']
#
#  transunet_up2_conv_after_conca  (None, 128, 128, 64  0          ['transunet_up2_conv_after_concat
#  t_0_activation (ReLU)          )                                _0_bn[0][0]']
#
#  transunet_up2_conv_after_conca  (None, 128, 128, 64  36864      ['transunet_up2_conv_after_concat
#  t_1 (Conv2D)                   )                                _0_activation[0][0]']
#
#  transunet_up2_conv_after_conca  (None, 128, 128, 64  256        ['transunet_up2_conv_after_concat
#  t_1_bn (BatchNormalization)    )                                _1[0][0]']
#
#  transunet_up2_conv_after_conca  (None, 128, 128, 64  0          ['transunet_up2_conv_after_concat
#  t_1_activation (ReLU)          )                                _1_bn[0][0]']
#
#  transunet_output (Conv2D)      (None, 128, 128, 1)  65          ['transunet_up2_conv_after_concat
#                                                                  _1_activation[0][0]']
#
#  transunet_output_activation (A  (None, 128, 128, 1)  0          ['transunet_output[0][0]']
#  ctivation)
#
# ==================================================================================================
# Total params: 55,696,385
# Trainable params: 55,689,857
# Non-trainable params: 6,528
# __________________________________________________________________________________________________

# %%
# Creamos funciones de todas las metricas

# Funcion con la métrica de dice_coeficient
def dice_coefficient(y_true, y_pred, smooth=1e-6):
    """
    Calcula Dice Coefficient por imagen y luego promedio sobre batch.
    """
    y_pred = tf.cast(y_pred, tf.float32)
    y_true = tf.cast(y_true, tf.float32)

    # Aplanamos por imagen: shape (batch, H*W*C)
    y_true_f = tf.reshape(y_true, [tf.shape(y_true)[0], -1])
    y_pred_f = tf.reshape(y_pred, [tf.shape(y_pred)[0], -1])

    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=1)
    denominator = tf.reduce_sum(y_true_f, axis=1) + tf.reduce_sum(y_pred_f, axis=1)

    dice = (2. * intersection + smooth) / (denominator + smooth)
    return tf.reduce_mean(dice)

# ==========================
# IoU (Jaccard Index, batch-wise)
# ==========================
def iou(y_true, y_pred, smooth=1e-6, threshold=0.5):
    """
    Calcula Intersection over Union por imagen y luego promedio sobre batch.
    """
    y_pred_bin = tf.cast(y_pred > threshold, tf.float32)
    y_true = tf.cast(y_true, tf.float32)

    y_true_f = tf.reshape(y_true, [tf.shape(y_true)[0], -1])
    y_pred_f = tf.reshape(y_pred_bin, [tf.shape(y_pred_bin)[0], -1])

    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=1)
    union = tf.reduce_sum(y_true_f + y_pred_f, axis=1) - intersection

    iou_score = (intersection + smooth) / (union + smooth)
    return tf.reduce_mean(iou_score)

# %%
# Ahora creamos una función para las callbacks y asi "mejorar" el entrenamiento

# Funcion de pérdida para IoU y mejorar el entrenamiento
def iou_loss(y_true, y_pred, smooth=1e-6):
    """
    IoU Loss para segmentación binaria.
    Se minimiza 1 - IoU.
    """
    y_pred = tf.cast(y_pred, tf.float32)
    y_true = tf.cast(y_true, tf.float32)

    # Aplanamos
    y_true_f = tf.reshape(y_true, [tf.shape(y_true)[0], -1])
    y_pred_f = tf.reshape(y_pred, [tf.shape(y_pred)[0], -1])

    # Intersección y unión
    intersection = tf.reduce_sum(y_true_f * y_pred_f, axis=1)
    union = tf.reduce_sum(y_true_f + y_pred_f, axis=1) - intersection

    iou_score = (intersection + smooth) / (union + smooth)

    # Loss = 1 - IoU
    return 1 - tf.reduce_mean(iou_score)


# Ahora creamos los callbacks para mejorar el entrenamiento

# ModelCheckpoint para guardar el mejor modelo
#checkpoint_cb_min_loss = ModelCheckpoint(
  #  "best_model_transunet_resnet50_min_loss.h5",
   # monitor="val_loss",  # o "val_iou"
   # save_best_only=True,
   # mode="min",
   # verbose=1
#)

#checkpoint_cb_max_dice = ModelCheckpoint(
   # "best_model_transunet_resnet50_max_dice.h5",
   # monitor="val_dice_coefficient",  # o "val_iou"
    #save_best_only=True,
   # mode="max",
    #verbose=1
#)


# Earlystopping: para que deje de entrenar el modelo si no mejora
#earlystop_cb = EarlyStopping(
  #  monitor="val_loss",
   # patience=10,
   # restore_best_weights=True,
   # mode="min",
   #verbose=1
#)

# reduce_lr_cb: reduce el ratio de aprendizaje si el modelo no mejora
#reduce_lr_cb = ReduceLROnPlateau(
   # monitor="val_loss",
   # factor=0.7,
   # patience=7,
    #min_lr=1e-6,
   #mode="min",
   # verbose=1
#)
# Callbacks
checkpoint_cb = ModelCheckpoint(
    "best_model_transunet.h5",
    monitor="val_dice_coefficient",
    save_best_only=True,
    mode="max",
    verbose=1
)
earlystop_cb = EarlyStopping(
    monitor="val_dice_coefficient",
    patience=10,
    restore_best_weights=True,
    mode="max",
    verbose=1
)
reduce_lr_cb = ReduceLROnPlateau(
    monitor="val_dice_coefficient",
    factor=0.7,
    patience=7,
    min_lr=1e-6,
    mode="max",
    verbose=1
)

def combined_loss(y_true, y_pred):
    bce = tf.keras.losses.BinaryCrossentropy()(y_true, y_pred)
    iou_l = iou_loss(y_true, y_pred)
    return bce + iou_l

# Tensorboard: para visualizar pérdidas y métricas en tiempo real
tensorboard_cb = TensorBoard(
    log_dir="logs_trans_unet/",
    histogram_freq=1,
    write_graph=True,
    write_images=True
)
#callbacks = [checkpoint_cb_min_loss, checkpoint_cb_max_dice,earlystop_cb, reduce_lr_cb, tensorboard_cb]
callbacks = [checkpoint_cb, earlystop_cb, reduce_lr_cb, tensorboard_cb]

# %%
# Crear el optimizador
optimizador = Adam(learning_rate=1e-5)

model.compile(
    optimizer = optimizador,
    loss = combined_loss,
    metrics = [dice_coefficient, iou],
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 4
#       1 # Crear el optimizador
#       2 optimizador = Adam(learning_rate=1e-5)
# ----> 4 model.compile(
#       5     optimizer = optimizador,
#       6     loss = combined_loss,
#       7     metrics = [dice_coefficient, iou],
#       8 )
#
# NameError: name 'model' is not defined

# %%
history = model.fit(
    train_ds_unet,
    validation_data = val_ds_unet,
    epochs = 60,
    callbacks = callbacks,
)
# Out:
# Epoch 1/60
# 7778/7778 [==============================] - ETA: 0s - loss: 0.8776 - dice_coefficient: 0.5745 - iou: 0.5271
# Epoch 1: val_dice_coefficient improved from -inf to 0.70059, saving model to best_model_transunet.h5
# 7778/7778 [==============================] - 1060s 135ms/step - loss: 0.8776 - dice_coefficient: 0.5745 - iou: 0.5271 - val_loss: 0.6653 - val_dice_coefficient: 0.7006 - val_iou: 0.6368 - lr: 1.0000e-05
# Epoch 2/60
# 7778/7778 [==============================] - ETA: 0s - loss: 0.6993 - dice_coefficient: 0.6669 - iou: 0.6098
# Epoch 2: val_dice_coefficient improved from 0.70059 to 0.73984, saving model to best_model_transunet.h5
# 7778/7778 [==============================] - 
saving model to best_model_transunet.h5
# 7778/7778 [==============================] - 1131s 145ms/step - loss: 0.3771 - dice_coefficient: 0.8267 - iou: 0.7833 - val_loss: 0.3335 - val_dice_coefficient: 0.8605 - val_iou: 0.8102 - lr: 1.0000e-05
# Epoch 30/60
# 7778/7778 [==============================] - ETA: 0s - loss: 0.3734 - dice_coefficient: 0.8283 - iou: 0.7862
# Epoch 30: val_dice_coefficient did not improve from 0.86050
# 7778/7778 [==============================] - 1074s 138ms/step - loss: 0.3734 - dice_coefficient: 0.8283 - iou: 0.7862 - val_loss: 0.3342 - val_dice_coefficient: 0.8598 - val_iou: 0.8094 - lr: 1.0000e-05
# Epoch 31/60
# 7778/7778 [==============================] - ETA: 0s - loss: 0.3709 - dice_coefficient: 0.8295 - iou: 0.7873
# Epoch 31: val_dice_coefficient improved from 0.86050 to 0.86200, saving model to best_model_transunet.h5
# 7778/7778 [==============================] - 1121s 144ms/step - loss: 0.3709 - dice_coefficient: 0.8295 - iou: 0.7873 - val_loss: 0.3318 - val_dice_coefficient: 0.8620 - val_iou: 0.8096 - lr: 1.0000e-05
# Epoch 32/60
# 7778/7778 [==============================] - ETA: 0s - loss: 0.3676 - dice_coefficient: 0.8311 - iou: 0.7892
# Epoch 32: val_dice_coefficient did not improve from 0.86200
# 7778/7778 [==============================] - 1112s 142ms/step - loss: 0.3676 - dice_coefficient: 0.8311 - iou: 0.7892 - val_loss: 0.3633 - val_dice_coefficient: 0.8537 - val_iou: 0.7993 - lr: 1.0000e-05
# Epoch 33/60
#   46/7778 [..............................] - ETA: 14:43 - loss: 0.3523 - dice_coefficient: 0.8433 - iou: 0.7911
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 history = model.fit(
#       2     train_ds_unet,
#       3     validation_data = val_ds_unet,
#       4     epochs = 60,
#       5     callbacks = callbacks,
#       6 )
#
# File D:\MASTER IA\SEGUNDO CUATRIMESTRE\TAREAS\TRABAJO FIN DE MASTER\PROYECTO FIN DE MASTER\PROYECTO\TFMedificios\virtualEnvironments\.venv3.10\lib\site-packages\keras\utils\traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\MASTER IA\SEGUNDO CUATRIMESTRE\TAREAS\TRABAJO FIN DE MASTER\PROYECTO FIN DE MASTER\PROYECTO\TFMedificios\virtualEnvironments\.venv3.10\lib\site-packages\keras\engine\training.py:1564, in Model.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1556 with tf.profiler.experimental.Trace(
#    1557     "train",
#    1558     epoch_num=epoch,
#    (...)
#    1561     _r=1,
#    1562 ):
#    1563     callbacks.on_train_batch_begin(step)
# -> 1564     tmp_logs = self.train_function(iterator)
#    1565     if data_handler.should_sync:
#    1566         context.async_wait()
#
# File D:\MASTER IA\SEGUNDO CUATRIMESTRE\TAREAS\TRABAJO FIN DE MASTER\PROYECTO FIN DE MASTER\PROYECTO\TFMedificios\virtualEnvironments\.venv3.10\lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File D:\MASTER IA\SEGUNDO CUATRIMESTRE\TAREAS\TRABAJO FIN DE MASTER\PROYECTO FIN DE MASTER\PROYECTO\TFMedificios\virtualEnvironments\.venv3.10\lib\site-packages\tensorflow\python\eager\def_function.py:915, in Function.__call__(self, *args, **kwds)
#     912 compiler = "xla" if self._jit_compile else "nonXla"
#     914 with OptionalXlaContext(self._jit_compile):
# --> 915   result = self._call(*args, **kwds)
#     917 new_tracing_count = self.experimental_get_tracing_count()
#     918 without_tracing = (tracing_count == new_tracing_count)
#
# File D:\MASTER IA\SEGUNDO CUATRIMESTRE\TAREAS\TRABAJO FIN DE MASTER\PROYECTO FIN DE MASTER\PROYECTO\TFMedificios\virtualEnvironments\.venv3.10\lib\site-packages\tensorflow\python\eager\def_function.py:947, in Function._call(self, *args, **kwds)
#     944   self._lock.release()
#     945   # In this case we have created variables on the first call, so we run the
#     946   # defunned version which is guaranteed to never create variables.
# --> 947   return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     948 elif self._stateful_fn is not None:
#     949   # Release the lock early so that multiple threads can perform the call
#     950   # in parallel.
#     951   self._lock.release()
#
# File D:\MASTER IA\SEGUNDO CUATRIMESTRE\TAREAS\TRABAJO FIN DE MASTER\PROYECTO FIN DE MASTER\PROYECTO\TFMedificios\virtualEnvironments\.venv3.10\lib\site-packages\tensorflow\python\eager\function.py:2496, in Function.__call__(self, *args, **kwargs)
#    2493 with self._lock:
#    2494   (graph_function,
#    2495    filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2496 return graph_function._call_flat(
#    2497     filtered_flat_args, captured_inputs=graph_function.captured_inputs)
#
# File D:\MASTER IA\SEGUNDO CUATRIMESTRE\TAREAS\TRABAJO FIN DE MASTER\PROYECTO FIN DE MASTER\PROYECTO\TFMedificios\virtualEnvironments\.venv3.10\lib\site-packages\tensorflow\python\eager\function.py:1862, in ConcreteFunction._call_flat(self, args, captured_inputs, cancellation_manager)
#    1858 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1859 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1860     and executing_eagerly):
#    1861   # No tape is watching; skip to running the function.
# -> 1862   return self._build_call_outputs(self._inference_function.call(
#    1863       ctx, args, cancellation_manager=cancellation_manager))
#    1864 forward_backward = self._select_forward_and_backward_functions(
#    1865     args,
#    1866     possible_gradient_type,
#    1867     executing_eagerly)
#    1868 forward_function, args_with_tangents = forward_backward.forward()
#
# File D:\MASTER IA\SEGUNDO CUATRIMESTRE\TAREAS\TRABAJO FIN DE MASTER\PROYECTO FIN DE MASTER\PROYECTO\TFMedificios\virtualEnvironments\.venv3.10\lib\site-packages\tensorflow\python\eager\function.py:499, in _EagerDefinedFunction.call(self, ctx, args, cancellation_manager)
#     497 with _InterpolateFunctionError(self):
#     498   if cancellation_manager is None:
# --> 499     outputs = execute.execute(
#     500         str(self.signature.name),
#     501         num_outputs=self._num_outputs,
#     502         inputs=args,
#     503         attrs=attrs,
#     504         ctx=ctx)
#     505   else:
#     506     outputs = execute.execute_with_cancellation(
#     507         str(self.signature.name),
#     508         num_outputs=self._num_outputs,
#    (...)
#     511         ctx=ctx,
#     512         cancellation_manager=cancellation_manager)
#
# File D:\MASTER IA\SEGUNDO CUATRIMESTRE\TAREAS\TRABAJO FIN DE MASTER\PROYECTO FIN DE MASTER\PROYECTO\TFMedificios\virtualEnvironments\.venv3.10\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# KeyboardInterrupt:

# %%
# Ahora evaluamos el modelo
# Cogemos el modelo que guardamos durante el entrenamiento
# Definir la capa GELU personalizada
class GELU(Layer):
    def __init__(self, **kwargs):
        super(GELU, self).__init__(**kwargs)
    def call(self, inputs):
        return tf.keras.activations.gelu(inputs)
    def get_config(self):
        config = super(GELU, self).get_config()
        return config
modelo_guardado = load_model("best_model_transunet.h5",
                   custom_objects = {
                       "dice_coefficient": dice_coefficient,
                       "iou": iou,
                       "combined_loss": combined_loss,
                       # capas personalizadas de trans-UNet
                       "patch_extract": transformer_layers.patch_extract,
                       "patch_embedding": transformer_layers.patch_embedding,
                       "patch_merging": transformer_layers.patch_merging,
                       "patch_expanding": transformer_layers.patch_expanding,
                       "GELU": GELU
                   })

# %%
# Evaluar en validación
results = modelo_guardado.evaluate(val_ds_unet)
# Out:
# 2431/2431 [==============================] - 102s 39ms/step - loss: 0.3318 - dice_coefficient: 0.8620 - iou: 0.8095

# %%
# Ahora imprimimos la evaluación
print(f"Perdida (combinacion de IoU y binary_crossentropy): {results[0]:.3f}")
print(f"Metrica Dice Coefficient: {results[1]:.3f}")
print(f"Metrica IoU: {results[2]:.3f}")
# Out:
# Perdida (combinacion de IoU y binary_crossentropy): 0.332
# Metrica Dice Coefficient: 0.862
# Metrica IoU: 0.810

# %%
# Ahora visualizamos resultamos y vemos que tal
for batch in val_ds_unet.take(1):
    imagenes, mascaras = batch
    preds = modelo_guardado.predict(imagenes)

    # Visualizamos algunas imágenes
    num_ejemplos = 4
    plt.figure(figsize=(12, 6))
    for i in range(num_ejemplos):
        plt.subplot(num_ejemplos, 3, 3*i + 1)
        plt.imshow(imagenes[i].numpy())
        plt.title("Imagen original")
        plt.axis("off")

        plt.subplot(num_ejemplos, 3, 3*i + 2)
        plt.imshow(mascaras[i].numpy().squeeze(), cmap='gray')
        plt.title("Máscara real")
        plt.axis("off")

        plt.subplot(num_ejemplos, 3, 3*i + 3)
        plt.imshow(preds[i].squeeze(), cmap='gray')
        plt.title("Predicción")
        plt.axis("off")
    plt.show()
# Out:
# 1/1 [==============================] - 1s 761ms/step

# %%
from skimage.segmentation import watershed
from skimage.feature import peak_local_max
from scipy import ndimage as ndi
from matplotlib import colors

# Visualizamos algunos resultados con watershed
for batch in val_ds_unet.take(1):
    imagenes, mascaras = batch
    preds = modelo_guardado.predict(imagenes)

    num_ejemplos = 4
    plt.figure(figsize=(15, 8))
    for i in range(num_ejemplos):
        # Imagen original
        plt.subplot(num_ejemplos, 4, 4*i + 1)
        plt.imshow(imagenes[i].numpy())
        plt.title("Imagen original")
        plt.axis("off")

        # Máscara real
        plt.subplot(num_ejemplos, 4, 4*i + 2)
        plt.imshow(mascaras[i].numpy().squeeze(), cmap='gray')
        plt.title("Máscara real")
        plt.axis("off")

        # Predicción U-Net
        pred_binaria = (preds[i].squeeze() > 0.5).astype(np.uint8)

        plt.subplot(num_ejemplos, 4, 4*i + 3)
        plt.imshow(pred_binaria, cmap='gray')
        plt.title("Predicción")
        plt.axis("off")

        # Aplicar watershed
        distance_map = ndi.distance_transform_edt(pred_binaria)
        local_maxi = peak_local_max(distance_map, indices=False, labels=pred_binaria)
        markers, _ = ndi.label(local_maxi)
        labels_ws = watershed(-distance_map, markers, mask=pred_binaria)

        # Colorear labels
        cmap = plt.get_cmap("nipy_spectral")
        norm = colors.Normalize(vmin=0, vmax=labels_ws.max())
        labels_rgb = cmap(norm(labels_ws))[:, :, :3]

        # Superponer sobre imagen original
        alpha = 0.5
        overlay = (1 - alpha) * imagenes[i].numpy() + alpha * labels_rgb
        overlay = np.clip(overlay, 0, 1)

        plt.subplot(num_ejemplos, 4, 4*i + 4)
        plt.imshow(overlay)
        plt.title(f"Instancia (watershed)")
        plt.axis("off")

    plt.show()
# Out:
# 1/1 [==============================] - 0s 230ms/step
# C:\Users\kiler\AppData\Local\Temp\ipykernel_11568\2580759453.py:36: FutureWarning: indices argument is deprecated and will be removed in version 0.20. To avoid this warning, please do not use the indices argument. Please see peak_local_max documentation for more details.
#   local_maxi = peak_local_max(distance_map, indices=False, labels=pred_binaria)

# %% [markdown]
# Transformacion con watershed

# %%
# Cargamos la imagen
imagen = cv2.imread("../DATASETS/DATASET_FINAL/images.jpg")

# %%
img = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
img_resized = cv2.resize(img, (128,128))  # tamaño de entrada de tu U-Net
img_input = np.expand_dims(img_resized/255.0, axis=0)

# %%
# Cogemos la prediccion
prediccion_modelo = modelo_guardado.predict(img_input)[0,:,:,0]  # asumir salida (H,W,1)
# Out:
# 1/1 [==============================] - 0s 157ms/step

# %%
# Lo convertimos a mascaras binarias
mascaras_binarias_pred = (prediccion_modelo > 0.5).astype(np.uint8)

# %%
# Calculamos el mapa de distancia
distance_map = ndi.distance_transform_edt(mascaras_binarias_pred)

# %%
# Calculamos los máximos locales
local_maxi = local_maxima(distance_map)
markers, _ = ndi.label(local_maxi)

# %%
# Aplicamos watershed
labels = watershed(-distance_map, markers, mask=mascaras_binarias_pred)

# %%
# 1️⃣ Normalizamos labels para colorear
cmap = plt.get_cmap("nipy_spectral")  # colormap colorido
norm = colors.Normalize(vmin=0, vmax=labels.max())

# %%
# Convertimos labels a imagen RGB
labels_rgb = cmap(norm(labels))[:, :, :3]  # toma solo canales RGB, descarta alpha

# %%
# 2️⃣ Superponer sobre imagen original
alpha = 0.5  # transparencia del overlay
overlay = (1 - alpha) * (img_resized / 255.0) + alpha * labels_rgb
overlay = np.clip(overlay, 0, 1)  # asegurar que esté entre 0 y 1

# %%
# Visualizamos el resultado
plt.figure(figsize=(12,4))
plt.subplot(1,5,1); plt.imshow(img_resized); plt.title("Imagen original")
plt.subplot(1,5,2); plt.imshow(mascaras_binarias_pred, cmap="gray"); plt.title("Máscara U-Net")
plt.subplot(1,5,3); plt.imshow(distance_map, cmap="magma"); plt.title("Mapa de distancia")
plt.subplot(1,5,4); plt.imshow(labels, cmap="nipy_spectral"); plt.title("Watershed (instancias)")
plt.subplot(1,5,5); plt.imshow(overlay); plt.title(f"deteccion: {labels.max()}")
plt.show()

# Opcional: cuántos objetos detectó
print("Número de objetos detectados:", labels.max())
# Out:
# Número de objetos detectados: 107

# %%
# Cargamos la imagen
imagen = cv2.imread("../DATASETS/DATASET_FINAL/images.jpg")
img = cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB)
img_resized = cv2.resize(img, (128, 128))
img_input = np.expand_dims(img_resized / 255.0, axis=0)

# Predicción
prediccion_modelo = modelo_guardado.predict(img_input)[0, :, :, 0]
mascara_binaria = (prediccion_modelo > 0.5).astype(np.uint8)

# Mapa de distancia y watershed
distance_map = ndi.distance_transform_edt(mascara_binaria)
local_maxi = peak_local_max(distance_map, indices=False, footprint=np.ones((3,3)))
markers, _ = ndi.label(local_maxi)
labels = watershed(-distance_map, markers, mask=mascara_binaria)

# Colorear labels
cmap = plt.get_cmap("nipy_spectral")
norm = colors.Normalize(vmin=0, vmax=labels.max())
labels_rgb = cmap(norm(labels))[:, :, :3]

# Overlay con la imagen original
alpha = 0.5
overlay = np.clip((1 - alpha) * (img_resized / 255.0) + alpha * labels_rgb, 0, 1)

# Visualización
plt.figure(figsize=(18, 6))

plt.subplot(1, 3, 1)
plt.imshow(img_resized)
plt.title("Imagen original", fontsize=24)
plt.axis("off")

plt.subplot(1, 3, 2)
plt.imshow(mascara_binaria, cmap="gray")
plt.title("Predicción semántica (máscara)", fontsize=24)
plt.axis("off")

plt.subplot(1, 3, 3)
plt.imshow(overlay)
plt.title(f"Predicción por instancia (Watershed)", fontsize=24)
plt.axis("off")

plt.tight_layout()
plt.show()
# Out:
# 1/1 [==============================] - 0s 126ms/step
# C:\Users\kiler\AppData\Local\Temp\ipykernel_11568\4024286017.py:13: FutureWarning: indices argument is deprecated and will be removed in version 0.20. To avoid this warning, please do not use the indices argument. Please see peak_local_max documentation for more details.
#   local_maxi = peak_local_max(distance_map, indices=False, footprint=np.ones((3,3)))
